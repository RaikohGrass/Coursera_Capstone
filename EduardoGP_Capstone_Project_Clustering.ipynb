# %% [markdown]
# # CAPSTONE PROJECT - IBM Data Science Professional Certificate
# ## Author: Eduardo Gaona P.
#
# This Jupyter notebook will serve as the main platform to solve all the tasks from the capstone project of the IBM Data Science Professional Certificate

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests  # this module helps us to download a web page

# %% [markdown]
# Setting the URL for the table and using "request" to get the http information of it

# %%
url_wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# Using BeautifulSoup to get the "table" object

# %%
data  = requests.get(url_wiki).text
soup = BeautifulSoup(data,"html5lib")
tables = soup.find_all('table')[0] # in html table is represented by the tag <table>

# %% [markdown]
# Showing an example of an entry of the table

# %%
tables.find_all("td")[54]
# Out:
# <td style="vertical-align:top;">
# <p>M1J<br/><span style="font-size:85%;"><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a><br/>(<a href="/wiki/Scarborough_Village" title="Scarborough Village">Scarborough Village</a>)</span>
# </p>
# </td>

# %%
tables.find_all("td")[54].text
# Out:
# '\nM1JScarborough(Scarborough Village)\n\n'

# %% [markdown]
# Going through all the entries, extracting the text and forming the DataFrame

# %%
postal_codes = pd.DataFrame(columns=["PostalCode", "Borough", "Neighborhood"])

for PostalCode in tables.find_all("td"):
  if 'Not assigned' not in PostalCode.text:
    Code = PostalCode.text.replace('\n','')[0:3]
    Borough = PostalCode.text.replace('\n','')[3:PostalCode.text.replace('\n','').find('(')]
    Neighborhood = PostalCode.text.replace('\n','')[PostalCode.text.replace('\n','').find('(')+1:-1].replace(' / ',',')
    postal_codes = postal_codes.append({"PostalCode":Code, "Borough":Borough, "Neighborhood":Neighborhood}, ignore_index=True)

postal_codes.head()
# Out:
#   PostalCode           Borough                     Neighborhood
# 0        M3A        North York                        Parkwoods
# 1        M4A        North York                 Victoria Village
# 2        M5A  Downtown Toronto         Regent Park,Harbourfront
# 3        M6A        North York  Lawrence Manor,Lawrence Heights
# 4        M7A      Queen's Park    Ontario Provincial Government

# %%
postal_codes[postal_codes['PostalCode'] == 'M5G']
# Out:
#    PostalCode           Borough        Neighborhood
# 24        M5G  Downtown Toronto  Central Bay Street

# %%
postal_codes.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Adding the longitude and latitude of the neighborhoods

# %% [markdown]
# ### Using the .csv file:

# %%
pip install geocoder
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.4 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
Path_csv_loc = '/content/drive/MyDrive/Coursera/Geospatial_Coordinates.csv'
df_loc = pd.read_csv(Path_csv_loc)

# %%
df_loc.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
postal_codes_loc = postal_codes.set_index('PostalCode').join(df_loc.set_index('Postal Code')).reset_index()
postal_codes_loc.head()
# Out:
#   PostalCode           Borough  ...   Latitude  Longitude
# 0        M3A        North York  ...  43.753259 -79.329656
# 1        M4A        North York  ...  43.725882 -79.315572
# 2        M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3        M6A        North York  ...  43.718518 -79.464763
# 4        M7A      Queen's Park  ...  43.662301 -79.389494
#
# [5 rows x 5 columns]

# %%
postal_codes_loc[postal_codes_loc['PostalCode'] == 'M5G']
# Out:
#    PostalCode           Borough        Neighborhood   Latitude  Longitude
# 24        M5G  Downtown Toronto  Central Bay Street  43.657952 -79.387383

# %% [markdown]
# ### Using pgeocode to query for the location:

# %%
pip install pgeocode
# Out:
# Collecting pgeocode
#   Downloading pgeocode-0.3.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pgeocode) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pgeocode) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pgeocode) (2.23.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pgeocode) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pgeocode) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pgeocode) (2.10)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.3.0

# %%
import pgeocode
nomi = pgeocode.Nominatim('ca')
postal_codes_loc2 = postal_codes.copy()
latitude_list = []
longitude_list = []
for post_code in postal_codes['PostalCode']:
  location = nomi.query_postal_code(post_code)
  latitude_list.append(location.latitude)
  longitude_list.append(location.longitude)
postal_codes_loc2["Latitude"] = latitude_list
postal_codes_loc2["Longitude"] = longitude_list
postal_codes_loc2.head()
# Out:
#   PostalCode           Borough  ... Latitude  Longitude
# 0        M3A        North York  ...  43.7545   -79.3300
# 1        M4A        North York  ...  43.7276   -79.3148
# 2        M5A  Downtown Toronto  ...  43.6555   -79.3626
# 3        M6A        North York  ...  43.7223   -79.4504
# 4        M7A      Queen's Park  ...  43.6641   -79.3889
#
# [5 rows x 5 columns]

# %% [markdown]
# Getting the not found coordinates from the .csv based DataFrame

# %%
postal_codes_loc2[postal_codes_loc2["Latitude"].isna()]
# Out:
#    PostalCode  ... Longitude
# 76        M7R  ...       NaN
#
# [1 rows x 5 columns]

# %%
postal_codes_loc[postal_codes_loc["PostalCode"] == 'M7R']
# Out:
#    PostalCode  ...  Longitude
# 76        M7R  ... -79.615819
#
# [1 rows x 5 columns]

# %%
postal_codes_loc2[postal_codes_loc2["Latitude"].isna()] = postal_codes_loc[postal_codes_loc2["Latitude"].isna()]

# %%
postal_codes_loc2[postal_codes_loc2["PostalCode"] == 'M7R']
# Out:
#    PostalCode  ...  Longitude
# 76        M7R  ... -79.615819
#
# [1 rows x 5 columns]

# %% [markdown]
# ## Exploring the neighborhoods

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %%
location_Toronto = nomi.query_postal_code('M5A')
print("Toronto coordinates are: Latitude {}, Longitude {}".format(location_Toronto.latitude,location_Toronto.longitude))
# Out:
# Toronto coordinates are: Latitude 43.6555, Longitude -79.3626

# %%
# create map of New York using latitude and longitude values
toronto_map = folium.Map(location=[location_Toronto.latitude, location_Toronto.longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(postal_codes_loc2['Latitude'], postal_codes_loc2['Longitude'], postal_codes_loc2['Borough'], postal_codes_loc2['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)  
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_d50be96319454e46bf6daada40c3d482%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d50be96319454e46bf6daada40c3d482%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_d50be96319454e46bf6daada40c3d482%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_d50be96319454e46bf6daada40c3d482%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6555%2C%20-79.3626%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7cf3ec8a746b4c97a339bd59d5495672%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20% ...

# %%
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %% [markdown]
# We'll use the coordinates of Downtown Toronto to query for the locations in Toronto

# %%
postal_codes_loc2.head()
# Out:
#   PostalCode           Borough  ... Latitude  Longitude
# 0        M3A        North York  ...  43.7545   -79.3300
# 1        M4A        North York  ...  43.7276   -79.3148
# 2        M5A  Downtown Toronto  ...  43.6555   -79.3626
# 3        M6A        North York  ...  43.7223   -79.4504
# 4        M7A      Queen's Park  ...  43.6641   -79.3889
#
# [5 rows x 5 columns]

# %%
float(postal_codes_loc2[postal_codes_loc2["PostalCode"]=="M5A"].Latitude)
# Out:
# 43.6555

# %%
CLIENT_ID = 'OHKSEBZWUUR5QM1CDJRHMY3O2ASA0DZOS1DGXSM2WM2IM3QY' # your Foursquare ID
CLIENT_SECRET = 'THKUAKVGUXJU5WFKYZ3JHQSG5PKDJXQ1U345KCUCDXYFA1BM' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    float(postal_codes_loc2[postal_codes_loc2["PostalCode"]=="M5A"].Latitude), 
    float(postal_codes_loc2[postal_codes_loc2["PostalCode"]=="M5A"].Longitude), 
    radius, 
    LIMIT)
url # display URL

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60fe4432e3607e45a3d3db36'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53b8466a498e83df908c3f21-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '53b8466a498e83df908c3f21',
#        'location': {'address': '368 King St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Trinity St',
#         'distance': 225,
#         'formattedAddress': ['368 King St E (at Trinity St)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65355870959944,
#           'lng': -79.36180945913513}],
#         'lat': 43.65355870959944,
#         'lng': -79.36180945913513,
#         'state': 'ON'},
#        'name': 'Tandem Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54ea41ad498e9a11e9e13308-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '54ea41ad498e9a11e9e13308',
#        'location': {'address': '362 King St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Trinity St',
#         'distance': 233,
#         'formattedAddress': ['362 King St E (Trinity St)',
#          'Toronto ON M5A 1K9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653446723052674,
#           'lng': -79.3620167174383}],
#         'lat': 43.653446723052674,
#         'lng': -79.3620167174383,
#         'postalCode': 'M5A 1K9',
#         'state': 'ON'},
#        'name': 'Roselle Desserts',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af59046f964a520e0f921e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'id': '4af59046f964a520e0f921e3',
#        'location': {'address': '344 Queen St. E.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Parliament St.',
#         'distance': 154,
#         'formattedAddress': ['344 Queen St. E. (at Parliament St.)',
#          'Toronto ON M5A 1S8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65567455427388,
#           'lng': -79.3645032892494}],
#         'lat': 43.65567455427388,
#         'lng': -79.3645032892494,
#         'postalCode': 'M5A 1S8',
#         'state': 'ON'},
#        'name': 'Figs Breakfast & Lunch',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b58dd55f964a5208f6f28e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '4b58dd55f964a5208f6f28e3',
#        'location': {'address': '106 Sherbourne St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Adelaide St. East',
#         'distance': 189,
#         'formattedAddress': ['106 Sherbourne St. (at Adelaide St. East)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65551522261721,
#           'lng': -79.36495542526245}],
#         'lat': 43.65551522261721,
#         'lng': -79.36495542526245,
#         'state': 'ON'},
#        'name': 'The Yoga Lounge',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5619551a498e9e35fce2256b-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '5619551a498e9e35fce2256b',
#        'location': {'address': '118 Sumach St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Shuter St',
#         'distance': 384,
#         'formattedAddress': ['118 Sumach St (at Shuter St)',
#          'Toronto ON M5A 3J9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65813540553308,
#           'lng': -79.35951549011845}],
#         'lat': 43.65813540553308,
#         'lng': -79.35951549011845,
#         'neighborhood': 'Downtown Toronto',
#         'postalCode': 'M5A 3J9',
#         'state': 'ON'},
#        'name': 'Sumach Espresso',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50760559e4b0e8c7babe2497-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '50760559e4b0e8c7babe2497',
#        'location': {'address': '497 King Street East',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Sackville St and Sumach St',
#         'distance': 235,
#         'formattedAddress': ['497 King Street East (btwn Sackville St and Sumach St)',
#          'Toronto ON M5A 1L9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65473505045365,
#           'lng': -79.35987433132891}],
#         'lat': 43.65473505045365,
#         'lng': -79.35987433132891,
#         'postalCode': 'M5A 1L9',
#         'state': 'ON'},
#        'name': 'Body Blitz Spa East',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-566e1294498e3f6629006bc3-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '566e1294498e3f6629006bc3',
#        'location': {'address': '500 Queen Street East',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 332,
#         'formattedAddress': ['500 Queen Street East',
#          'Toronto ON M5A 1T9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65691857501867,
#           'lng': -79.35896684476664}],
#         'lat': 43.65691857501867,
#         'lng': -79.35896684476664,
#         'postalCode': 'M5A 1T9',
#         'state': 'ON'},
#        'name': 'Dominion Pub and Kitchen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ae5b91ff964a520a6a121e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'id': '4ae5b91ff964a520a6a121e3',
#        'location': {'address': '457 King St. E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Gilead Place',
#         'distance': 208,
#         'formattedAddress': ['457 King St. E (Gilead Place)',
#          'Toronto ON M5A 1L6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653946942635294,
#           'lng': -79.36114884214422}],
#         'lat': 43.653946942635294,
#         'lng': -79.36114884214422,
#         'postalCode': 'M5A 1L6',
#         'state': 'ON'},
#        'name': 'Morning Glory Cafe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39686393'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ada57aff964a520972121e3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '4ada57aff964a520972121e3',
#        'location': {'address': '274 Parliament St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Coatsworth St. & Shuter St.',
#         'distance': 411,
#         'formattedAddress': ['274 Parliament St (btwn Coatsworth St. & Shuter St.)',
#          'Toronto ON M5A 2Z6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.658444465539525,
#           'lng': -79.36568085121628}],
#         'lat': 43.658444465539525,
#         'lng': -79.36568085121628,
#         'postalCode': 'M5A 2Z6',
#         'state': 'ON'},
#        'name': 'Sukhothai',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51853a73498e4d97a8b20831-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '51853a73498e4d97a8b20831',
#        'location': {'address': '343 King St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Princess & Berkeley St',
#         'distance': 468,
#         'formattedAddress': ['343 King St E (btwn Princess & Berkeley St)',
#          'Toronto ON M5A 1L1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65189965670432,
#           'lng': -79.36560912104514}],
#         'lat': 43.65189965670432,
#         'lng': -79.36560912104514,
#         'postalCode': 'M5A 1L1',
#         'state': 'ON'},
#        'name': 'Rooster Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade8ea8f964a5205a7621e3-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d171941735',
#          'name': 'Event Space',
#          'pluralName': 'Event Spaces',
#          'primary': True,
#          'shortName': 'Event Space'}],
#        'id': '4ade8ea8f964a5205a7621e3',
#        'location': {'address': '315 Queen St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Berkeley St',
#         'distance': 266,
#         'formattedAddress': ['315 Queen St E (at Berkeley St)',
#          'Toronto ON M5A 1S7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65512324174501,
#           'lng': -79.36587330410705}],
#         'lat': 43.65512324174501,
#         'lng': -79.36587330410705,
#         'postalCode': 'M5A 1S7',
#         'state': 'ON'},
#        'name': 'Berkeley Church',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5612b1cc498e3dd742af0dc8-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '5612b1cc498e3dd742af0dc8',
#        'location': {'address': '573 King St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at St Lawrence St',
#         'distance': 462,
#         'formattedAddress': ['573 King St E (at St Lawrence St)',
#          'Toronto ON M5A 4L3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65636850543279,
#           'lng': -79.35697968750694}],
#         'lat': 43.65636850543279,
#         'lng': -79.35697968750694,
#         'postalCode': 'M5A 4L3',
#         'state': 'ON'},
#        'name': 'Impact Kitchen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-574c229e498ebb5c6b257902-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a37',
#          'name': 'Distribution Center',
#          'pluralName': 'Distribution Centers',
#          'primary': True,
#          'shortName': 'Distributor'}],
#        'id': '574c229e498ebb5c6b257902',
#        'location': {'address': '461 Cherry St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 446,
#         'formattedAddress': ['461 Cherry St', 'Toronto ON M5A 0H7', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65324910177244,
#           'lng': -79.35800826343677}],
#         'lat': 43.65324910177244,
#         'lng': -79.35800826343677,
#         'postalCode': 'M5A 0H7',
#         'state': 'ON'},
#        'name': 'Cooper Koo Family YMCA',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad776eef964a520e20a21e3-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4ad776eef964a520e20a21e3',
#        'location': {'address': '260 King St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Princess',
#         'distance': 471,
#         'formattedAddress': ['260 King St E (Princess)',
#          'Toronto ON M5R 4L5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.652249517927686,
#           'lng': -79.36635530500347}],
#         'lat': 43.652249517927686,
#         'lng': -79.36635530500347,
#         'postalCode': 'M5R 4L5',
#         'state': 'ON'},
#        'name': 'Mangia and Bevi Resto-Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58c7fbf7424f9373e6427e99-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '58c7fbf7424f9373e6427e99',
#        'location': {'address': '351 King St E, 60',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 471,
#         'formattedAddress': ['351 King St E, 60',
#          'Toronto ON M5A 1L1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.651613,
#           'lng': -79.364917}],
#         'lat': 43.651613,
#         'lng': -79.364917,
#         'postalCode': 'M5A 1L1',
#         'state': 'ON'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e8b7fa1cc2112f67517660a-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4e8b7fa1cc2112f67517660a',
#        'location': {'address': '30 Eastern Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Sackville St.',
#         'distance': 335,
#         'formattedAddress': ['30 Eastern Ave (Sackville St.)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65331304337331,
#           'lng': -79.35972538072777}],
#         'lat': 43.65331304337331,
#         'lng': -79.35972538072777,
#         'state': 'ON'},
#        'name': 'The Extension Room',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8c46f3f964a5200cc832e3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4b8c46f3f964a5200cc832e3',
#        'location': {'address': '70 Berkley St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Adelaide St.',
#         'distance': 351,
#         'formattedAddress': ['70 Berkley St. (at Adelaide St.)',
#          'Toronto ON M5A 2W6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65275554626444,
#           'lng': -79.36475283805089}],
#         'lat': 43.65275554626444,
#         'lng': -79.36475283805089,
#         'postalCode': 'M5A 2W6',
#         'state': 'ON'},
#        'name': 'Alumnae Theatre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50899387e4b055a756b254fc-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'primary': True,
#          'shortName': 'Food Truck'}],
#        'id': '50899387e4b055a756b254fc',
#        'location': {'address': '1017 Dufferin St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Bloor St West',
#         'distance': 399,
#         'formattedAddress': ['1017 Dufferin St (Bloor St West)',
#          'Toronto ON M6H 4B5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65836361668554,
#           'lng': -79.36558277878224}],
#         'lat': 43.65836361668554,
#         'lng': -79.36558277878224,
#         'postalCode': 'M6H 4B5',
#         'state': 'ON'},
#        'name': 'I Love Churros',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad8d551f964a5201f1521e3-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'primary': True,
#          'shortName': 'Electronics'}],
#        'id': '4ad8d551f964a5201f1521e3',
#        'location': {'address': '496 Queen St E',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Sumach',
#         'distance': 292,
#         'formattedAddress': ['496 Queen St E (at Sumach)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65704640025721,
#           'lng': -79.35966695607046}],
#         'lat': 43.65704640025721,
#         'lng': -79.35966695607046,
#         'state': 'ON'},
#        'name': 'Vistek',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b2cf78cf964a52077cb24e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b2cf78cf964a52077cb24e3',
#        'location': {'address': '481 Queen St. East',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Sumach St',
#         'distance': 327,
#         'formattedAddress': ['481 Queen St. East (Sumach St)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.656820970004496,
#           'lng': -79.3589698353747}],
#         'lat': 43.656820970004496,
#         'lng': -79.3589698353747,
#         'state': 'ON'},
#        'name': 'Savoury Grounds',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8acdfdf964a520378232e3-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'primary': True,
#          'shortName': 'Beer Store'}],
#        'id': '4b8acdfdf964a520378232e3',
#        'location': {'address': '28 River Street',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Queen St E',
#         'distance': 484,
#         'formattedAddress': ['28 River Street (Queen St E)',
#          'Toronto ON M5A 3N9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.657773,
#           'lng': -79.3574632}],
#         'lat': 43.657773,
#         'lng': -79.3574632,
#         'postalCode': 'M5A 3N9',
#         'state': 'ON'},
#        'name': 'The Beer Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5f5e9e92fd233501367b169c-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '5f5e9e92fd233501367b169c',
#        'location': {'address': 'Unit 3, 146 Sumach St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Shuter St',
#         'distance': 408,
#         'formattedAddress': ['Unit 3, 146 Sumach St (at Shuter St)',
#          'Toronto ON M5A 0P7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.658522,
#           'lng': -79.359717}],
#         'lat': 43.658522,
#         'lng': -79.359717,
#         'postalCode': 'M5A 0P7',
#         'state': 'ON'},
#        'name': 'Kibo Sushi House 希',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5292543a498ec4d4c99c0c64-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '50aa9e744b90af0d42d5de0e',
#          'name': 'Health Food Store',
#          'pluralName': 'Health Food Stores',
#          'primary': True,
#          'shortName': 'Health Food Store'}],
#        'id': '5292543a498ec4d4c99c0c64',
#        'location': {'address': '518 King Street East',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Sumach',
#         'distance': 449,
#         'formattedAddress': ['518 King Street East (Sumach)',
#          'Toronto ON M5A 1M1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.656264585886454,
#           'lng': -79.35711882680904}],
#         'lat': 43.656264585886454,
#         'lng': -79.35711882680904,
#         'postalCode': 'M5A 1M1',
#         'state': 'ON'},
#        'name': 'The Healthy Road',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dffdf2152b10e7477991327-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'primary': True,
#          'shortName': 'Playground'}],
#        'id': '4dffdf2152b10e7477991327',
#        'location': {'address': '48 Shuter St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at River St.',
#         'distance': 458,
#         'formattedAddress': ['48 Shuter St. (at River St.)',
#          'Toronto ON M5A 1X9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65848972987893,
#           'lng': -79.35869192148257}],
#         'lat': 43.65848972987893,
#         'lng': -79.35869192148257,
#         'postalCode': 'M5A 1X9',
#         'state': 'ON'},
#        'name': 'Sumach-Shuter Parkette',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Corktown, Toronto',
#   'headerLocation': 'Corktown',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.660000004500006,
#     'lng': -79.3563918719477},
#    'sw': {'lat': 43.6509999955, 'lng': -79.36880812805231}},
#   'totalResults': 24}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      name      categories        lat        lng
# 0           Tandem Coffee     Coffee Shop  43.653559 -79.361809
# 1        Roselle Desserts          Bakery  43.653447 -79.362017
# 2  Figs Breakfast & Lunch  Breakfast Spot  43.655675 -79.364503
# 3         The Yoga Lounge     Yoga Studio  43.655515 -79.364955
# 4         Sumach Espresso     Coffee Shop  43.658135 -79.359515

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues_Toronto = getNearbyVenues(postal_codes_loc2['Neighborhood'],postal_codes_loc2['Latitude'],postal_codes_loc2['Longitude'])

# %%
venues_Toronto.head()
# Out:
#        Neighborhood  ...        Venue Category
# 0         Parkwoods  ...                  Park
# 1         Parkwoods  ...  Fast Food Restaurant
# 2         Parkwoods  ...     Food & Drink Shop
# 3  Victoria Village  ...          Hockey Arena
# 4  Victoria Village  ...           Coffee Shop
#
# [5 rows x 7 columns]

# %%
print('Number of categories found: {}'.format(len(venues_Toronto["Venue Category"].unique())))
# Out:
# Number of categories found: 261

# %% [markdown]
# There are some venues that are in fact neighborhoods. We can therefore drop them to avoid confusion

# %%
venues_Toronto[venues_Toronto["Venue Category"]=='Neighborhood']
# Out:
#                                     Neighborhood  ...  Venue Category
# 429                                  The Beaches  ...    Neighborhood
# 574                           Central Bay Street  ...    Neighborhood
# 722                       Richmond,Adelaide,King  ...    Neighborhood
# 1095  Brockton,Parkdale Village,Exhibition Place  ...    Neighborhood
# 1851                              Enclave of M5E  ...    Neighborhood
#
# [5 rows x 7 columns]

# %%
venues_Toronto = venues_Toronto.drop(venues_Toronto[venues_Toronto["Venue Category"]=='Neighborhood'].index)

# %% [markdown]
# To be able to cluster the neighborhoods we will use assigned locations. In order to quantify them we can use the "one hot" coding and group by neighborhood.

# %%
venues_Toronto_quant = pd.concat([venues_Toronto['Neighborhood'],pd.get_dummies(venues_Toronto[['Venue Category']], prefix="", prefix_sep="")],axis=1)
venues_Toronto_quant.head()
# Out:
#        Neighborhood  Accessories Store  ...  Women's Store  Yoga Studio
# 0         Parkwoods                  0  ...              0            0
# 1         Parkwoods                  0  ...              0            0
# 2         Parkwoods                  0  ...              0            0
# 3  Victoria Village                  0  ...              0            0
# 4  Victoria Village                  0  ...              0            0
#
# [5 rows x 261 columns]

# %% [markdown]
# After having our one hot coded DataFrame we can then group by each neighborhood and take the mean for each categoery. This will give us a footprint of the how each neighborhood is characterized

# %%
venues_Toronto_quant= venues_Toronto_quant.groupby("Neighborhood").mean().reset_index()
venues_Toronto_quant
# Out:
#                                      Neighborhood  ...  Yoga Studio
# 0                                      Agincourt)  ...          0.0
# 1                           Alderwood,Long Branch  ...          0.0
# 2   Bathurst Manor,Wilson Heights,Downsview North  ...          0.0
# 3                                 Bayview Village  ...          0.0
# 4                Bedford Park,Lawrence Manor East  ...          0.0
# ..                                            ...  ...          ...
# 95                         Willowdale,Newtonbrook  ...          0.0
# 96                                         Woburn  ...          0.0
# 97                               Woodbine Heights  ...          0.0
# 98                                York Mills West  ...          0.0
# 99                        York Mills,Silver Hills  ...          0.0
#
# [100 rows x 261 columns]

# %% [markdown]
# ### Most common venues per Neighborhood

# %% [markdown]
# We can look at the 5 most common venues in each neighborhood:

# %%
num_venues = 10
dict_freq_venues = {}
for i,neighborhood_i in enumerate(venues_Toronto_quant["Neighborhood"]):
  values_neighborhood = venues_Toronto_quant.iloc[i].values[1:]
  dict_freq_venues[neighborhood_i] = [venues_Toronto_quant.iloc[i].index.to_list()[1:][x] for x in sorted(range(len(values_neighborhood)), key=lambda k: values_neighborhood[k])[::-1]][0:num_venues]

# %%
dict_freq_venues

# %% [markdown]
# Let´s create a DataFrame with the ten most common venues for each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
Toronto_neighborhood_venues = pd.DataFrame(columns=columns)
Toronto_neighborhood_venues["Neighborhood"] = venues_Toronto_quant["Neighborhood"]

# %%
dict_freq_venues[Toronto_neighborhood_venues.iloc[0,0]]
# Out:
# ['Skating Rink',
#  'Latin American Restaurant',
#  'Breakfast Spot',
#  'Badminton Court',
#  'Yoga Studio']

# %%
Toronto_neighborhood_venues.shape
for i,neighborhood in enumerate(Toronto_neighborhood_venues["Neighborhood"]):
  Toronto_neighborhood_venues.iloc[i,1:] = dict_freq_venues[neighborhood]

# %%
Toronto_neighborhood_venues.head()
# Out:
#                                     Neighborhood  ... 10th Most Common Venue
# 0                                     Agincourt)  ...        Warehouse Store
# 1                          Alderwood,Long Branch  ...            Wings Joint
# 2  Bathurst Manor,Wilson Heights,Downsview North  ...            Wings Joint
# 3                                Bayview Village  ...             Whisky Bar
# 4               Bedford Park,Lawrence Manor East  ...              Pet Store
#
# [5 rows x 11 columns]

# %% [markdown]
# We can join our DataFrames to include the geographical information of the Neighborhood

# %%
Toronto_complete = postal_codes_loc2.set_index('Neighborhood').join(Toronto_neighborhood_venues.set_index('Neighborhood')).reset_index()
Toronto_complete.head()
# Out:
#                       Neighborhood  ... 10th Most Common Venue
# 0                        Parkwoods  ...  Vietnamese Restaurant
# 1                 Victoria Village  ...            Wings Joint
# 2         Regent Park,Harbourfront  ...             Playground
# 3  Lawrence Manor,Lawrence Heights  ...          Jewelry Store
# 4    Ontario Provincial Government  ...    Japanese Restaurant
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Clustering the neighborhoods

# %% [markdown]
# Using our quantified DataFrame we can cluster our neighborhoods

# %%
# set number of clusters
kclusters = 4

toronto_clustering = venues_Toronto_quant.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 1, 3, 0, 0, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# Adding the cluster label to our quantified DataFrame and then joining it with our complete DataFrame of venues:

# %%
venues_Toronto_quant["Cluster"] = kmeans.labels_
venues_Toronto_quant
# Out:
#                                      Neighborhood  ...  Cluster
# 0                                      Agincourt)  ...        0
# 1                           Alderwood,Long Branch  ...        1
# 2   Bathurst Manor,Wilson Heights,Downsview North  ...        1
# 3                                 Bayview Village  ...        3
# 4                Bedford Park,Lawrence Manor East  ...        0
# ..                                            ...  ...      ...
# 95                         Willowdale,Newtonbrook  ...        2
# 96                                         Woburn  ...        1
# 97                               Woodbine Heights  ...        2
# 98                                York Mills West  ...        3
# 99                        York Mills,Silver Hills  ...        3
#
# [100 rows x 262 columns]

# %%
Toronto_complete2 = Toronto_complete.set_index('Neighborhood').join(venues_Toronto_quant.set_index('Neighborhood')["Cluster"]).reset_index().dropna()

# %%
Toronto_complete2.head()
# Out:
#                       Neighborhood PostalCode  ... 10th Most Common Venue  Cluster
# 0                        Parkwoods        M3A  ...  Vietnamese Restaurant      3.0
# 1                 Victoria Village        M4A  ...            Wings Joint      0.0
# 2         Regent Park,Harbourfront        M5A  ...             Playground      0.0
# 3  Lawrence Manor,Lawrence Heights        M6A  ...          Jewelry Store      0.0
# 4    Ontario Provincial Government        M7A  ...    Japanese Restaurant      0.0
#
# [5 rows x 16 columns]

# %%
# create map
map_clusters = folium.Map(location=[location_Toronto.latitude, location_Toronto.longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_complete2['Latitude'], Toronto_complete2['Longitude'], Toronto_complete2['Neighborhood'], Toronto_complete2['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_5e408af155b94c48858980e2feedff67%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5e408af155b94c48858980e2feedff67%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_5e408af155b94c48858980e2feedff67%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_5e408af155b94c48858980e2feedff67%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6555%2C%20-79.3626%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_30a211cbca1946218870d99a63bfde52%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20% ...

# %% [markdown]
# ## Exploring the clusters

# %% [markdown]
# ### Cluster 1:

# %%
Cluster1 = Toronto_complete2.loc[Toronto_complete2['Cluster'] == 0, Toronto_complete2.columns[[0] + list(range(5, Toronto_complete2.shape[1]))]]
Cluster1.head()
# Out:
#                       Neighborhood  ... Cluster
# 1                 Victoria Village  ...     0.0
# 2         Regent Park,Harbourfront  ...     0.0
# 3  Lawrence Manor,Lawrence Heights  ...     0.0
# 4    Ontario Provincial Government  ...     0.0
# 9         Garden District, Ryerson  ...     0.0
#
# [5 rows x 12 columns]

# %%
Cluster1['1st Most Common Venue'].value_counts()
# Out:
# Coffee Shop                   11
# Café                           5
# Park                           5
# Sushi Restaurant               4
# Trail                          3
# Hotel                          3
# Skating Rink                   2
# Clothing Store                 2
# Italian Restaurant             2
# Rental Service                 1
# Sports Bar                     1
# Greek Restaurant               1
# Japanese Restaurant            1
# Pub                            1
# Baseball Field                 1
# Grocery Store                  1
# Bar                            1
# Women's Store                  1
# Construction & Landscaping     1
# Tennis Court                   1
# Ramen Restaurant               1
# Brewery                        1
# Burrito Place                  1
# Portuguese Restaurant          1
# Shoe Store                     1
# Intersection                   1
# Light Rail Station             1
# Restaurant                     1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# This cluster is for neighborhoods with coffe shops

# %% [markdown]
# ### Cluster 2:

# %%
Cluster2 = Toronto_complete2.loc[Toronto_complete2['Cluster'] == 1, Toronto_complete2.columns[[0] + list(range(5, Toronto_complete2.shape[1]))]]
Cluster2.head()
# Out:
#                                          Neighborhood  ... Cluster
# 6                                       Malvern,Rouge  ...     1.0
# 8                      Parkview Hill,Woodbine Gardens  ...     1.0
# 10                                          Glencairn  ...     1.0
# 11  West Deane Park,Princess Gardens,Martin Grove,...  ...     1.0
# 17  Eringate,Bloordale Gardens,Old Burnhamthorpe,M...  ...     1.0
#
# [5 rows x 12 columns]

# %%
Cluster2['1st Most Common Venue'].value_counts()
# Out:
# Pizza Place              6
# Home Service             2
# Supermarket              2
# Sandwich Place           2
# Convenience Store        2
# Nightclub                1
# Fast Food Restaurant     1
# Shopping Mall            1
# Shopping Plaza           1
# Korean BBQ Restaurant    1
# Ice Cream Shop           1
# Grocery Store            1
# Indian Restaurant        1
# Coffee Shop              1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# This cluster is for neighborhoods with pizza places

# %% [markdown]
# ### Cluster 3:

# %%
Cluster3 = Toronto_complete2.loc[Toronto_complete2['Cluster'] == 2, Toronto_complete2.columns[[0] + list(range(5, Toronto_complete2.shape[1]))]]
Cluster3.head()
# Out:
#                     Neighborhood  ... Cluster
# 5               Islington Avenue  ...     2.0
# 14              Woodbine Heights  ...     2.0
# 27             Hillcrest Village  ...     2.0
# 52        Willowdale,Newtonbrook  ...     2.0
# 69  High Park,The Junction South  ...     2.0
#
# [5 rows x 12 columns]

# %%
Cluster3['1st Most Common Venue'].value_counts()
# Out:
# Residential Building (Apartment / Condo)    2
# Pharmacy                                    2
# Playground                                  1
# Video Store                                 1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# This cluster is rather small and not so straight forward to describe

# %% [markdown]
# ### Cluster 4:

# %%
Cluster4 = Toronto_complete2.loc[Toronto_complete2['Cluster'] == 3, Toronto_complete2.columns[[0] + list(range(5, Toronto_complete2.shape[1]))]]
Cluster4.head()
# Out:
#                        Neighborhood  ... Cluster
# 0                         Parkwoods  ...     3.0
# 7                    Don Mills)Nort  ...     3.0
# 13  Don Mills)South(Flemingdon Park  ...     3.0
# 32              Scarborough Village  ...     3.0
# 35               The Danforth  East  ...     3.0
#
# [5 rows x 12 columns]

# %%
Cluster4['1st Most Common Venue'].value_counts()
# Out:
# Park                  5
# Trail                 3
# Pool                  3
# Playground            2
# Photography Studio    1
# Spa                   1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# This neighborhood has mostly parks and trails
